# %%
import os
import json
import codecs
import numpy as np
import tensorflow as tf
import yaml
import DM_process_v1 as DM_process

os.environ["CUDA_VISIBLE_DEVICES"] = '1'
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
tf.__version__
# Out:
# '2.3.0'

# %%
params = {
    'batch_size': 16,
    'epochs': 300,
    'drops' : [0.1],
    'heads':16,
    'head_size':8,
    'out_dim':64
         }

# %%
with open('./DM_char.json', mode='r', encoding='utf-8') as f:
    dicts = json.load(f)

# %%
path = '../stories/all_stories.yml'
with open(path, 'r', encoding='utf-8') as f:
    dataset = yaml.load(f.read(),Loader=yaml.Loader)

# %%
action2id = dicts['action2id']
intent2id = dicts['intent2id']
slots2id = dicts['entities2id']
id2action = dicts['id2action']
id2intent = dicts['id2intent']
id2slots = dicts['id2entities']

# %%
previous_action_len = len(action2id)
# print(previous_action_len)
slots_len = len(slots2id)
# print(slots_len)
user_intent_len = len(intent2id)
# print(user_intent_len)

# %%
data_set = DM_process.split_data(dataset)

# %%
previous_action, slots, user_intent, action = DM_process.extract_conv_data(data_set,action2id,slots2id,intent2id)

# %%
def Dataset(previous_action_inputs, slots_inputs,user_intent_inputs,pre_action):
    dataset = tf.data.Dataset.from_tensor_slices(({
    "previous_action_inputs" : previous_action_inputs,
    "slots_inputs" : slots_inputs,
    "user_intent_inputs" : user_intent_inputs
    },
    {
        "pre_action" : pre_action
    }))
    dataset = dataset.batch(params['batch_size'])
    return dataset

# %%
train_dataset =  Dataset(previous_action, slots, user_intent, action)

# %%
from tensorflow.keras.layers import Layer

class MultiHeadAttention(Layer):
    def __init__(
            self,
            heads,
            head_size,
            out_dim=None,
            use_bias=True,
            #             max_value = 1,
            #             min_value = -1
            **kwargs
    ):
        super(MultiHeadAttention, self).__init__(**kwargs)
        self.heads = heads
        self.head_size = head_size
        self.out_dim = out_dim
        self.use_bias = use_bias

    def build(self, input_shape):
        super(MultiHeadAttention, self).build(input_shape)
        self.q_dense = tf.keras.layers.Dense(
            units=self.head_size * self.heads,
            use_bias=self.use_bias,
            name='q'

        )
        self.k_dense = tf.keras.layers.Dense(
            units=self.head_size * self.heads,
            use_bias=self.use_bias,
            name='k'
        )
        self.v_dense = tf.keras.layers.Dense(
            units=self.head_size * self.heads,
            use_bias=self.use_bias,
            name='v'
        )
        self.o_dense = tf.keras.layers.Dense(
            units=self.out_dim,
            use_bias=self.use_bias,
            name='o'
        )

    def call(self, inputs):
        q = inputs
        k = inputs
        v = inputs
        # 线性变化
        qw = self.q_dense(q)
        kw = self.k_dense(k)
        vw = self.v_dense(v)
        # 形状变换
        qw = tf.reshape(qw, (-1, tf.shape(q)[1], self.heads, self.head_size))
        kw = tf.reshape(kw, (-1, tf.shape(q)[1], self.heads, self.head_size))
        vw = tf.reshape(vw, (-1, tf.shape(q)[1], self.heads, self.head_size))
        # attention
        qkv_inputs = [qw, kw, vw]
        o = self.pay_attention_to(qkv_inputs)
        o = tf.reshape(o, (-1, tf.shape(o)[1], self.head_size * self.heads))
        o = self.o_dense(o)
        return o

    def pay_attention_to(self, inputs):
        (qw, kw, vw) = inputs[:3]
        a = tf.einsum('bjhd,bkhd->bhjk', qw, kw)
        a = a / self.head_size ** 0.5
        A = tf.nn.softmax(a)
        o = tf.einsum('bhjk,bkhd -> bjhd', A, vw)
        return o

# %%
from tensorflow.keras.layers import concatenate, Dropout,LayerNormalization, Dense, add

class Encoder(tf.keras.models.Model):
    def __init__(
            self,
            layer_count,
            **kwargs
    ):
        super(Encoder, self).__init__(**kwargs)
        self.layer_count = layer_count

    def build(self, input_shape):
        self.MultiHeadAttention = MultiHeadAttention(heads=params['heads'], head_size=params['head_size'], out_dim=params['out_dim'])
        self.dropout= Dropout(0.1)
        self.l1 = LayerNormalization(name='normal')
        self.feed1 = Dense(params['out_dim'], activation='relu',name='feed')
        self.feed2 = Dense(params['out_dim'],name='feed1')
        self.dropout1 = Dropout(0.1)
        self.l_1 = LayerNormalization(name='normal1')

    def call(self, inputs):
        state = inputs
        for i in range(self.layer_count):
            att = self.MultiHeadAttention(state)
            att1 = self.dropout(att)
            ad = add([att1, state])
            l1 = self.l1(ad)
            feed1 = self.feed1(l1)
            feed2 = self.feed2(feed1)
            dropout_1 = self.dropout1(feed2)
            ad1 = add([l1,dropout_1])
            l_1 = self.l_1(ad1)
            state = l_1
        return state

# %%
tf.keras.backend.clear_session()
previous_action_inputs = tf.keras.layers.Input(shape=(previous_action_len,), name = 'previous_action_inputs')
slots_inputs = tf.keras.layers.Input(shape = (slots_len,), name = 'slots_inputs')
user_intent_inputs = tf.keras.layers.Input(shape = (user_intent_len,), name = 'user_intent_inputs')

previous_action_embed = tf.keras.layers.Embedding(128,64)(previous_action_inputs)
slots_embed = tf.keras.layers.Embedding(128,64)(slots_inputs)
user_intent_embed = tf.keras.layers.Embedding(128,64)(user_intent_inputs)

utter_inputs = tf.keras.layers.concatenate([previous_action_embed,slots_embed,user_intent_embed],axis=1)
atten = Encoder(layer_count=3)(utter_inputs)
bilstm = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(128,return_sequences=True))(atten)
x_conv = tf.keras.layers.GlobalAveragePooling1D()(bilstm)
pre_action = tf.keras.layers.Dense(previous_action_len, activation='softmax',name = 'pre_action')(x_conv)
model = tf.keras.Model([previous_action_inputs,slots_inputs,user_intent_inputs],pre_action)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# previous_action_inputs (InputLa [(None, 35)]         0
# __________________________________________________________________________________________________
# slots_inputs (InputLayer)       [(None, 13)]         0
# __________________________________________________________________________________________________
# user_intent_inputs (InputLayer) [(None, 43)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 35, 64)       8192        previous_action_inputs[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 13, 64)       8192        slots_inputs[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 43, 64)       8192        user_intent_inputs[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 91, 64)       0           embedding[0][0]
#                                                                  embedding_1[0][0]
#                                                                  embedding_2[0][0]
# __________________________________________________________________________________________________
# encoder (Encoder)               (None, 91, 64)       41792       concatenate[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 91, 256)      148992      encoder[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 256)          0           bidirectional[0][0]
# __________________________________________________________________________________________________
# pre_action (Dense)              (None, 35)           8995        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 224,355
# Trainable params: 224,355
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
losses = {'pre_action': 'categorical_crossentropy'}
metrics = {'pre_action': ['accuracy']}
optimizer = tf.keras.optimizers.Nadam()
model.compile(optimizer, loss=losses, metrics=metrics)

# %%
file_path = '../DM_model_weight/DM_weight_encoder.h5'
# checkpoint = tf.keras.callbacks.ModelCheckpoint(file_path,
#                                                         save_weights_only=False, save_best_only=True)
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(patience=50, factor=0.5)
callbacks_list = [learning_rate_reduction]

# %%
model.fit(train_dataset,epochs=params['epochs'])
# Out:
# Epoch 1/300
# 14/14 [==============================] - 0s 19ms/step - loss: 3.6820 - accuracy: 0.1754
# Epoch 2/300
# 14/14 [==============================] - 0s 20ms/step - loss: 3.5134 - accuracy: 0.1374
# Epoch 3/300
# 14/14 [==============================] - 0s 20ms/step - loss: 3.3554 - accuracy: 0.1754
# Epoch 4/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.3364 - accuracy: 0.1754
# Epoch 5/300
# 14/14 [==============================] - 0s 20ms/step - loss: 3.3176 - accuracy: 0.1374
# Epoch 6/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.2989 - accuracy: 0.1374
# Epoch 7/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.2835 - accuracy: 0.1374
# Epoch 8/300
# 14/14 [==============================] - 0s 21ms/step - loss: 3.2716 - accuracy: 0.1374
# Epoch 9/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.2620 - accuracy: 0.1374
# Epoch 10/300
# 14/14 [==============================] - 0s 21ms/step - loss: 3.2528 - accuracy: 0.1374
# Epoch 11/300
# 14/14 [==============================] - 0s 21ms/step - loss: 3.2448 - accuracy: 0.1374
# Epoch 12/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.2387 - accuracy: 0.1374
# Epoch 13/300
# 14/14 [==============================] - 0s 19ms/step - loss: 3.2311 - accuracy: 0.1374
# Epoch 14/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.2246 - accuracy: 0.1374
# Epoch 15/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.2182 - accuracy: 0.1374
# Epoch 16/300
# 14/14 [==============================] - 0s 20ms/step - loss: 3.2125 - accuracy: 0.1374
# Epoch 17/300
# 14/14 [==============================] - 0s 20ms/step - loss: 3.2059 - accuracy: 0.1374
# Epoch 18/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.2015 - accuracy: 0.1185
# Epoch 19/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.1949 - accuracy: 0.1137
# Epoch 20/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.1903 - accuracy: 0.1137
# Epoch 21/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.1858 - accuracy: 0.1137
# Epoch 22/300
# 14/14 [==============================] - 0s 20ms/step - loss: 3.1821 - accuracy: 0.1137
# Epoch 23/300
# 14/14 [==============================] - 0s 23ms/step - loss: 3.1761 - accuracy: 0.1137
# Epoch 24/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.1728 - accuracy: 0.1137
# Epoch 25/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.1710 - accuracy: 0.1137
# Epoch 26/300
# 14/14 [==============================] - 0s 19ms/step - loss: 3.1666 - accuracy: 0.1137
# Epoch 27/300
# 14/14 [==============================] - 0s 20ms/step - loss: 3.1627 - accuracy: 0.1137
# Epoch 28/300
# 14/14 [==============================] - 0s 21ms/step - loss: 3.1583 - accuracy: 0.1137
# Epoch 29/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.1544 - accuracy: 0.1137
# Epoch 30/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.1530 - accuracy: 0.1137
# Epoch 31/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.1487 - accuracy: 0.1137
# Epoch 32/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.1468 - accuracy: 0.1137
# Epoch 33/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.1436 - accuracy: 0.1137
# Epoch 34/300
# 14/14 [==============================] - 0s 19ms/step - loss: 3.1427 - accuracy: 0.1137
# Epoch 35/300
# 14/14 [==============================] - 0s 19ms/step - loss: 3.1396 - accuracy: 0.1137
# Epoch 36/300
# 14/14 [==============================] - 0s 20ms/step - loss: 3.1388 - accuracy: 0.1137
# Epoch 37/300
# 14/14 [==============================] - 0s 19ms/step - loss: 3.1361 - accuracy: 0.1137
# Epoch 38/300
# 14/14 [==============================] - 0s 20ms/step - loss: 3.1334 - accuracy: 0.1137
# Epoch 39/300
# 14/14 [==============================] - 0s 20ms/step - loss: 3.1326 - accuracy: 0.1137
# Epoch 40/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.1293 - accuracy: 0.1137
# Epoch 41/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.1271 - accuracy: 0.1137
# Epoch 42/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.1261 - accuracy: 0.1137
# Epoch 43/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.1235 - accuracy: 0.1137
# Epoch 44/300
# 14/14 [==============================] - 0s 20ms/step - loss: 3.1226 - accuracy: 0.1137
# Epoch 45/300
# 14/14 [==============================] - 0s 18ms/step - loss: 3.1206 - accuracy: 0.1232
# Epoch 46/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.1187 - accuracy: 0.1280
# Epoch 47/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.1178 - accuracy: 0.1801
# Epoch 48/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.1156 - accuracy: 0.1896
# Epoch 49/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.1139 - accuracy: 0.1896
# Epoch 50/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.1127 - accuracy: 0.1896
# Epoch 51/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.1108 - accuracy: 0.1896
# Epoch 52/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.
300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0417 - accuracy: 0.1896
# Epoch 243/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0417 - accuracy: 0.1896
# Epoch 244/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0423 - accuracy: 0.1896
# Epoch 245/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0416 - accuracy: 0.1896
# Epoch 246/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0421 - accuracy: 0.1896
# Epoch 247/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0410 - accuracy: 0.1896
# Epoch 248/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0417 - accuracy: 0.1896
# Epoch 249/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0421 - accuracy: 0.1896
# Epoch 250/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0417 - accuracy: 0.1896
# Epoch 251/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0418 - accuracy: 0.1896
# Epoch 252/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0417 - accuracy: 0.1896
# Epoch 253/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0411 - accuracy: 0.1896
# Epoch 254/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0406 - accuracy: 0.1896
# Epoch 255/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0408 - accuracy: 0.1896
# Epoch 256/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0408 - accuracy: 0.1896
# Epoch 257/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.0416 - accuracy: 0.1896
# Epoch 258/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.0412 - accuracy: 0.1896
# Epoch 259/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0411 - accuracy: 0.1896
# Epoch 260/300
# 14/14 [==============================] - 0s 15ms/step - loss: 3.0411 - accuracy: 0.1896
# Epoch 261/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0413 - accuracy: 0.1896
# Epoch 262/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0408 - accuracy: 0.1896
# Epoch 263/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0416 - accuracy: 0.1896
# Epoch 264/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0405 - accuracy: 0.1896
# Epoch 265/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0408 - accuracy: 0.1896
# Epoch 266/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0403 - accuracy: 0.1896
# Epoch 267/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0409 - accuracy: 0.1896
# Epoch 268/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0407 - accuracy: 0.1896
# Epoch 269/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0397 - accuracy: 0.1896
# Epoch 270/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0403 - accuracy: 0.1896
# Epoch 271/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0409 - accuracy: 0.1896
# Epoch 272/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0399 - accuracy: 0.1896
# Epoch 273/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0399 - accuracy: 0.1896
# Epoch 274/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0400 - accuracy: 0.1896
# Epoch 275/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0391 - accuracy: 0.1896
# Epoch 276/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0389 - accuracy: 0.1896
# Epoch 277/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0393 - accuracy: 0.1896
# Epoch 278/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0394 - accuracy: 0.1896
# Epoch 279/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0386 - accuracy: 0.1896
# Epoch 280/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0401 - accuracy: 0.1896
# Epoch 281/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0387 - accuracy: 0.1896
# Epoch 282/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0392 - accuracy: 0.1896
# Epoch 283/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.0391 - accuracy: 0.1896
# Epoch 284/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0385 - accuracy: 0.1896
# Epoch 285/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0374 - accuracy: 0.1896
# Epoch 286/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.0382 - accuracy: 0.1896
# Epoch 287/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.0385 - accuracy: 0.1896
# Epoch 288/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0383 - accuracy: 0.1896
# Epoch 289/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0376 - accuracy: 0.1896
# Epoch 290/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0375 - accuracy: 0.1896
# Epoch 291/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.0378 - accuracy: 0.1896
# Epoch 292/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0381 - accuracy: 0.1896
# Epoch 293/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0385 - accuracy: 0.1896
# Epoch 294/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0380 - accuracy: 0.1896
# Epoch 295/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0372 - accuracy: 0.1896
# Epoch 296/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0380 - accuracy: 0.1896
# Epoch 297/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.0373 - accuracy: 0.1896
# Epoch 298/300
# 14/14 [==============================] - 0s 17ms/step - loss: 3.0372 - accuracy: 0.1896
# Epoch 299/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0382 - accuracy: 0.1896
# Epoch 300/300
# 14/14 [==============================] - 0s 16ms/step - loss: 3.0369 - accuracy: 0.1896

# %%
4# model.save_weights('../DM_model_weight/DM_weight_629.h5')

# %%
model.save(file_path)
