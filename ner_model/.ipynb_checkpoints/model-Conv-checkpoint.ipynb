# %%
import os
import json
import codecs
import numpy as np
import tensorflow as tf
os.environ["CUDA_VISIBLE_DEVICES"] = '1'
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
params = {
    'batch_size': 64,
    'lr' : 0.001,
    'max_sent_len': 20,
    'epochs': 500,
    'drops' : [0.1]
         }

# %%
def extract_data(data_path):
    """
    意图识别抽取出label
    槽位识别与填充作为命名实体识别问题，对每一个字进行实体标注, ate_time', 'B-target', 'I-date_time', 'I-date_time', 'I-operation', 'I-date_time', 'I-date_time']
[ ]:
￼
​B E I O S
    """
    with codecs.open(data_path,"r",encoding="utf-8") as fp:
        data = json.load(fp)
    texts = [example['text'].replace(" ","") for example in data]
    intent_labels = [example['intent'] for example in data]
    
    slots_ners = []
    count = 0
    for example in data:
        if 'entities' in example.keys():
            text = example['text']
            ner = ['O'] * len(text)
            slots = example['entities']
            for key,val in slots.items():
                start_idx = text.find(val)
                end_idx = start_idx + len(val) -1
                if len(val) == 1:
                    ner[start_idx] = 'S-' + key
                else:
                    ner[start_idx] = 'B-' + key
                    ner[end_idx] = 'E-'+ key
                    for idx in range(start_idx+1, end_idx):
                        ner[idx] = 'I-' + key
        else:
            text = example['text']
            ner = ['O'] * len(text)
        slots_ners.append(ner)
    print('texts len: ', len(texts))
    print('intent_lables len: ',len(intent_labels))
    print('slots_ners len: ', len(slots_ners))
    return texts, intent_labels, slots_ners

# %%
# data_path ="./dataset/data_v2.json"
# max_sent_len = params["max_sent_len"]
# texts, intent_labels, slots_ners = extract_data(data_path)
# train_text = [d for i , d in enumerate(texts) if i % 10 != 0]
# valid_text = [d for i , d in enumerate(texts) if i % 10 == 0]
# train_intent = [d for i , d in enumerate(intent_labels) if i % 10 != 0]
# valid_intent = [d for i , d in enumerate(intent_labels) if i % 10 == 0]
# train_ner = [d for i , d in enumerate(slots_ners) if i % 10 != 0]
# valid_ner = [d for i , d in enumerate(slots_ners) if i % 10 == 0]

# %%
data_path ="../dataset/data_v2.json"
max_sent_len = params["max_sent_len"]
texts, intent_labels, slots_ners = extract_data(data_path)
# l = len(texts) // params['batch_size']
# texts = texts[:l*params['batch_size']]
# intent =  intent[:l*params['batch_size']]
# slots_ners = slots_ners[:l*params['batch_size']]
train_text = [d for i , d in enumerate(texts) if i % 10 != 0]
train_l = len(train_text) // params['batch_size']
train_text = train_text[:train_l*params['batch_size']]
valid_text = [d for i , d in enumerate(texts) if i % 10 == 0]
valid_l = len(valid_text) // params['batch_size']
valid_text = valid_text[:valid_l*params['batch_size']]

train_intent = [d for i , d in enumerate(intent_labels) if i % 10 != 0]
train_intent = train_intent[:train_l*params['batch_size']]
valid_intent = [d for i , d in enumerate(intent_labels) if i % 10 == 0]
valid_intent = valid_intent[:valid_l*params['batch_size']]

train_ner = [d for i , d in enumerate(slots_ners) if i % 10 != 0]
train_ner = train_ner[:train_l*params['batch_size']]
valid_ner = [d for i , d in enumerate(slots_ners) if i % 10 == 0]
valid_ner =valid_ner[:valid_l*params['batch_size']]
# Out:
# texts len:  2542
# intent_lables len:  2542
# slots_ners len:  2542

# %%
with open('/home/ai/hgm/Smart_Home/ner_model/char_conv.json', mode='r', encoding='utf-8') as f:
    dicts = json.load(f)
    
char2id = dicts['char2id']
id2char = dicts['id2char']
intent2id = dicts['intent2id']
id2intent = dicts['id2intent']
slot2id = dicts['slot2id']
id2slot = dicts['id2slot']

params['intent_num'] = len(intent2id)
params['slot_num'] = len(slot2id)../char_6.17.json
params['id2intent'] = id2intent
params['id2slot'] = id2slot

# %%
def trans2labelid(vocab, labels, max_sent_len):
    labels = [vocab[label] for label in labels]
    if len(labels) < max_sent_len:
        labels += [0] * (max_sent_len - len(labels))
    else:
        labels = labels[:max_sent_len]
    return labels

# %%
def read_data(txt_seqs, intent_labels, slot_ners,char2id,intent2id,slot2id,max_sent_len):
    dataset_text_labels = []
    dataset_intent_labels = []
    dataset_ner_labels = []
    
    for index in range(len(txt_seqs)):
        dataset_text_labels.append(trans2labelid(char2id,txt_seqs[index],max_sent_len))
        dataset_intent_labels.append([intent2id[intent_labels[index]]])
        dataset_ner_labels.append(trans2labelid(slot2id,slot_ners[index],max_sent_len))
    dataset_text_labels = np.array(dataset_text_labels)
    dataset_intent_labels = np.array(dataset_intent_labels)
    dataset_ner_labels = np.array(dataset_ner_labels)
    
    return dataset_text_labels, dataset_intent_labels, dataset_ner_labels

# %%
tarin_seq, train_intent, train_ner =  read_data(train_text, train_intent, train_ner,char2id,intent2id,slot2id,max_sent_len)

# %%
valid_seq, valid_intent, valid_ner =  read_data(valid_text, valid_intent, valid_ner,char2id,intent2id,slot2id,max_sent_len)

# %%
def Dataset(txt_seqs, dataset_intent_labels, dataset_ner_labels):
    dataset = tf.data.Dataset.from_tensor_slices(({
    "Input" : txt_seqs
    },
    {
        "pre_intent":dataset_intent_labels,
        
        "pre_ner":dataset_ner_labels
    }))
    dataset = dataset.batch(params['batch_size'])
    return dataset

# %%
train_dataset = Dataset(tarin_seq, train_intent, train_ner)
valid_dataset = Dataset(valid_seq, valid_intent, valid_ner)

# %%
params['intent_num'] = len(intent2id)
params['slot_num'] = len(slot2id)
params['id2intent'] = id2intent
params['id2slot'] = id2slot

# %%
tf.keras.backend.clear_session()
text_inputs = tf.keras.layers.Input(shape=(20,),name='Input')
embed = tf.keras.layers.Embedding(500,32)(text_inputs)
bilstm = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(64,return_sequences=True))(embed)
x_in = tf.keras.layers.LayerNormalization()(bilstm)
x_conv = tf.keras.layers.GlobalAveragePooling1D()(x_in)
pre_intent = tf.keras.layers.Dense(params['intent_num'],\
            activation='sigmoid',name = 'pre_intent')(x_conv)
x_ner  = tf.keras.layers.LayerNormalization()(bilstm)
pre_slot = tf.keras.layers.Dense(params['slot_num'],activation='sigmoid',name = 'pre_ner')(x_ner)
model = tf.keras.Model(text_inputs,[pre_intent,pre_slot])
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 20)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 20, 32)       16000       Input[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 20, 128)      37632       embedding[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 20, 128)      256         bidirectional[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 128)          0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 20, 128)      256         bidirectional[0][0]
# __________________________________________________________________________________________________
# pre_intent (Dense)              (None, 55)           7095        global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# pre_ner (Dense)                 (None, 20, 36)       4644        layer_normalization_1[0][0]
# ==================================================================================================
# Total params: 65,883
# Trainable params: 65,883
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
losses = {'pre_intent':'sparse_categorical_crossentropy','pre_ner':'sparse_categorical_crossentropy'}
metrics = { 'pre_intent': ['accuracy'],'pre_ner': ['accuracy']}
optimizer = tf.keras.optimizers.Adam(params['lr'])
model.compile(optimizer, loss=losses, metrics=metrics)

# %%
file_path = '../ner_model_weight/model_conv.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(file_path,
                                                        save_weights_only=False, save_best_only=True)
learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(patience=50, factor=0.5)
callbacks_list = [checkpoint,learning_rate_reduction]

# %%
model.fit(train_dataset,epochs=params['epochs'],validation_data=valid_dataset,callbacks=callbacks_list)
# Out:
# Epoch 1/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0169 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0099 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9935 - val_loss: 0.4687 - val_pre_intent_loss: 0.2440 - val_pre_ner_loss: 0.2247 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9664
# Epoch 2/500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0209 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0139 - pre_intent_accuracy: 0.9942 - pre_ner_accuracy: 0.9932 - val_loss: 0.4327 - val_pre_intent_loss: 0.2355 - val_pre_ner_loss: 0.1972 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9674
# Epoch 3/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0278 - pre_intent_loss: 0.0070 - pre_ner_loss: 0.0208 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9915 - val_loss: 0.4796 - val_pre_intent_loss: 0.2527 - val_pre_ner_loss: 0.2268 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9664
# Epoch 4/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0282 - pre_intent_loss: 0.0070 - pre_ner_loss: 0.0213 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9910 - val_loss: 0.4351 - val_pre_intent_loss: 0.2268 - val_pre_ner_loss: 0.2083 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9667
# Epoch 5/500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0371 - pre_intent_loss: 0.0070 - pre_ner_loss: 0.0301 - pre_intent_accuracy: 0.9942 - pre_ner_accuracy: 0.9888 - val_loss: 0.4859 - val_pre_intent_loss: 0.2556 - val_pre_ner_loss: 0.2303 - val_pre_intent_accuracy: 0.9688 - val_pre_ner_accuracy: 0.9609
# Epoch 6/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0552 - pre_intent_loss: 0.0072 - pre_ner_loss: 0.0480 - pre_intent_accuracy: 0.9937 - pre_ner_accuracy: 0.9858 - val_loss: 0.4531 - val_pre_intent_loss: 0.2314 - val_pre_ner_loss: 0.2217 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9641
# Epoch 7/500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0498 - pre_intent_loss: 0.0076 - pre_ner_loss: 0.0422 - pre_intent_accuracy: 0.9942 - pre_ner_accuracy: 0.9857 - val_loss: 0.4148 - val_pre_intent_loss: 0.2117 - val_pre_ner_loss: 0.2031 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9667
# Epoch 8/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0354 - pre_intent_loss: 0.0076 - pre_ner_loss: 0.0278 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9882 - val_loss: 0.5069 - val_pre_intent_loss: 0.2976 - val_pre_ner_loss: 0.2093 - val_pre_intent_accuracy: 0.9531 - val_pre_ner_accuracy: 0.9669
# Epoch 9/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0310 - pre_intent_loss: 0.0097 - pre_ner_loss: 0.0213 - pre_intent_accuracy: 0.9929 - pre_ner_accuracy: 0.9900 - val_loss: 0.4678 - val_pre_intent_loss: 0.2650 - val_pre_ner_loss: 0.2028 - val_pre_intent_accuracy: 0.9427 - val_pre_ner_accuracy: 0.9682
# Epoch 10/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0217 - pre_intent_loss: 0.0103 - pre_ner_loss: 0.0115 - pre_intent_accuracy: 0.9942 - pre_ner_accuracy: 0.9929 - val_loss: 0.4573 - val_pre_intent_loss: 0.2558 - val_pre_ner_loss: 0.2016 - val_pre_intent_accuracy: 0.9531 - val_pre_ner_accuracy: 0.9693
# Epoch 11/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0272 - pre_intent_loss: 0.0157 - pre_ner_loss: 0.0115 - pre_intent_accuracy: 0.9915 - pre_ner_accuracy: 0.9927 - val_loss: 0.4375 - val_pre_intent_loss: 0.2421 - val_pre_ner_loss: 0.1954 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9698
# Epoch 12/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0209 - pre_intent_loss: 0.0099 - pre_ner_loss: 0.0109 - pre_intent_accuracy: 0.9955 - pre_ner_accuracy: 0.9928 - val_loss: 0.4843 - val_pre_intent_loss: 0.2769 - val_pre_ner_loss: 0.2074 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9688
# Epoch 13/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0173 - pre_intent_loss: 0.0074 - pre_ner_loss: 0.0099 - pre_intent_accuracy: 0.9937 - pre_ner_accuracy: 0.9936 - val_loss: 0.4834 - val_pre_intent_loss: 0.2795 - val_pre_ner_loss: 0.2039 - val_pre_intent_accuracy: 0.9531 - val_pre_ner_accuracy: 0.9701
# Epoch 14/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0152 - pre_intent_loss: 0.0070 - pre_ner_loss: 0.0082 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9939 - val_loss: 0.4835 - val_pre_intent_loss: 0.2777 - val_pre_ner_loss: 0.2058 - val_pre_intent_accuracy: 0.9531 - val_pre_ner_accuracy: 0.9698
# Epoch 15/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0145 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0076 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9941 - val_loss: 0.4860 - val_pre_intent_loss: 0.2785 - val_pre_ner_loss: 0.2074 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9698
# Epoch 16/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0142 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0073 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9942 - val_loss: 0.4846 - val_pre_intent_loss: 0.2766 - val_pre_ner_loss: 0.2079 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9698
# Epoch 17/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0140 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0071 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9942 - val_loss: 0.4847 - val_pre_intent_loss: 0.2759 - val_pre_ner_loss: 0.2088 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9693
# Epoch 18/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0139 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0069 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9944 - val_loss: 0.4830 - val_pre_intent_loss: 0.2740 - val_pre_ner_loss: 0.2089 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9693
# Epoch 19/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0138 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0068 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9943 - val_loss: 0.4829 - val_pre_intent_loss: 0.2734 - val_pre_ner_loss: 0.2095 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9690
# Epoch 20/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0137 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0067 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9944 - val_loss: 0.4814 - val_pre_intent_loss: 0.2717 - val_pre_ner_loss: 0.2097 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9693
# Epoch 21/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0136 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0067 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9944 - val_loss: 0.4816 - val_pre_intent_loss: 0.2714 - val_pre_ner_loss: 0.2102 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9690
# Epoch 22/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0135 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0066 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4803 - val_pre_intent_loss: 0.2697 - val_pre_ner_loss: 0.2106 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9690
# Epoch 23/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4810 - val_pre_intent_loss: 0.2698 - val_pre_ner_loss: 0.2111 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 24/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4794 - val_pre_intent_loss: 0.2679 - val_pre_ner_loss: 0.2116 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9690
# Epoch 25/500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9944 - val_loss: 0.4806 - val_pre_intent_loss: 0.2685 - val_pre_ner_loss: 0.2121 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 26/500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0133 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0064 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9944 - val_loss: 0.4784 - val_pre_intent_loss: 0.2661 - val_pre_ner_loss: 0.2123 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 27/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0133 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0064 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4801 - val_pre_intent_loss: 0.2673 - val_pre_ner_loss: 0.2128 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9682
# Epoch 28/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0133 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0064 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4774 - val_pre_intent_loss: 0.2645 - val_pre_ner_loss: 0.2129 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 29/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0133 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0064 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4796 - val_pre_intent_loss: 0.2663 - val_pre_ner_loss: 0.2134 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9682
# Epoch 30/500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0133 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4773 - val_pre_intent_loss: 0.2635 - val_pre_ner_loss: 0.2138 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9682
# Epoch 31/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4791 - val_pre_intent_loss: 0.2653 - val_pre_ner_loss: 0.2139 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9682
# Epoch 32/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4778 - val_pre_intent_loss: 0.2629 - val_pre_ner_loss: 0.2150 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9688
# Epoch 33/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4785 - val_pre_intent_loss: 0.2643 - val_pre_ner_loss: 0.2142 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9685
# Epoch 34/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4780 - val_pre_intent_loss: 0.2621 - val_pre_ner_loss: 0.2159 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9690
# Epoch 35/500
# 35/35 [==============================] - 0s 13ms/step - loss: 0.0135 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0066 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4776 - val_pre_intent_loss: 0.2632 - val_pre_ner_loss: 0.2144 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9682
# Epoch 36/500
# 35/35 [==============================] - 0s 14ms/step - loss: 0.0135 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0066 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4782 - val_pre_intent_loss: 0.2614 - val_pre_ner_loss: 0.2168 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9695
# Epoch 37/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0137 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0068 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9944 - val_loss: 0.4746 - val_pre_intent_loss: 0.2612 - val_pre_ner_loss: 0.2134 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9685
# Epoch 38/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0136 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0067 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4784 - val_pre_intent_loss: 0.2614 - val_pre_ner_loss: 0.2170 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9698
# Epoch 39/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0137 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0068 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4718 - val_pre_intent_loss: 0.2586 - val_pre_ner_loss: 0.2132 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9685
# Epoch 40/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0136 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0067 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4786 - val_pre_intent_loss: 0.2616 - val_pre_ner_loss: 0.2171 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9693
# Epoch 41/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0066 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4708 - val_pre_intent_loss: 0.2565 - val_pre_ner_loss: 0.2143 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9688
# Epoch 42/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0136 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0067 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4807 - val_pre_intent_loss: 0.2624 - val_pre_ner_loss: 0.2183 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9685
# Epoch 43/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4732 - val_pre_intent_loss: 0.2570 - val_pre_ner_loss: 0.2161 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 44/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0066 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4808 - val_pre_intent_loss: 0.2619 - val_pre_ner_loss: 0.2189 - val_pre_intent_accuracy: 0.9635 - val_pre_ner_accuracy: 0.9685
# Epoch 45/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0133 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0064 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4776 - val_pre_intent_loss: 0.2591 - val_pre_ner_loss: 0.2185 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 46/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0133 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4816 - val_pre_intent_loss: 0.2623 - val_pre_ner_loss: 0.2194 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 47/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4790 - val_pre_intent_loss: 0.2594 - val_pre_ner_loss: 0.2195 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 48/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4813 - val_pre_intent_loss: 0.2619 - val_pre_ner_loss: 0.2194 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 49/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0134 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9947 - val_loss: 0.4798 - val_pre_intent_loss: 0.2596 - val_pre_ner_loss: 0.2202 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 50/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0133 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0065 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4822 - val_pre_intent_loss: 0.2621 - val_pre_ner_loss: 0.2201 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9680
# Epoch 51/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0132 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0063 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9946 - val_loss: 0.4805 - val_pre_intent_loss: 0.2597 - val_pre_ner_loss: 0.2209 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 52/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0131 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0063 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4849 - val_pre_intent_loss: 0.2633 - val_pre_ner_loss: 0.2216 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9680
# Epoch 53/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0131 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0062 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9946 - val_loss: 0.4820 - val_pre_intent_loss: 0.2602 - val_pre_ner_loss: 0.2218 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 54/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0131 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0062 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4861 - val_pre_intent_loss: 0.2638 - val_pre_ner_loss: 0.2224 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9680
# Epoch 55/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0130 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0062 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9946 - val_loss: 0.4827 - val_pre_intent_loss: 0.2606 - val_pre_ner_loss: 0.2221 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 56/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0131 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0062 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4875 - val_pre_intent_loss: 0.2643 - val_pre_ner_loss: 0.2232 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 57/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0130 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0062 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9946 - val_loss: 0.4825 - val_pre_intent_loss: 0.2605 - val_pre_ner_loss: 0.2220 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 58/500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0130 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0061 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4858 - val_pre_intent_loss: 0.2631 - val_pre_ner_loss: 0.2228 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 59/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0127 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0058 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4872 - val_pre_intent_loss: 0.2638 - val_pre_ner_loss: 0.2234 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 60/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0058 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4877 - val_pre_intent_loss: 0.2641 - val_pre_ner_loss: 0.2236 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 61/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0058 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4883 - val_pre_intent_loss: 0.2644 - val_pre_ner_loss: 0.2238 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 62/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0058 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4888 - val_pre_intent_loss: 0.2648 - val_pre_ner_loss: 0.2240 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 63/500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0058 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4891 - val_pre_intent_loss: 0.2650 - val_pre_ner_loss: 0.2241 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 64/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4895 - val_pre_intent_loss: 0.2653 - val_pre_ner_loss: 0.2242 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 65/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4898 - val_pre_intent_loss: 0.2655 - val_pre_ner_loss: 0.2243 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 66/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9945 - val_loss: 0.4901 - val_pre_intent_loss: 0.2657 - val_pre_ner_loss: 0.2244 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 67/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4904 - val_pre_intent_loss: 0.2659 - val_pre_ner_loss: 0.2245 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 68/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4907 - val_pre_intent_loss: 0.2661 - val_pre_ner_loss: 0.2246 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 69/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4910 - val_pre_intent_loss: 0.2663 - val_pre_ner_loss: 0.2247 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9688
# Epoch 70/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4913 - val_pre_intent_loss: 0.2665 - val_pre_ner_loss: 0.2248 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 71/500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4915 - val_pre_intent_loss: 0.2666 - val_pre_ner_loss: 0.2249 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 72/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9946 - val_loss: 0.4918 - val_pre_intent_loss: 0.2668 - val_pre_ner_loss: 0.2250 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 73/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9946 - val_loss: 0.4921 - val_pre_intent_loss: 0.2670 - val_pre_ner_loss: 0.2251 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 74/500
# 35/35 [==============================] - 0s 13ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9946 - val_loss: 0.4924 - val_pre_intent_loss: 0.2672 - val_pre_ner_loss: 0.2252 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9680
# Epoch 75/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9946 - val_loss: 0.4927 - val_pre_intent_loss: 0.2673 - val_pre_ner_loss: 0.2253 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 76/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9946 - val_loss: 0.4929 - val_pre_intent_loss: 0.2676 - val_pre_ner_loss: 0.2254 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9680
# Epoch 77/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9946 - val_loss: 0.4932 - val_pre_intent_loss: 0.2677 - val_pre_ner_loss: 0.2256 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 78/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9946 - val_loss: 0.4935 - val_pre_intent_loss: 0.2679 - val_pre_ner_loss: 0.2256 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9680
# Epoch 79/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9946 - val_loss: 0.4938 - val_pre_intent_loss: 0.2679 - val_pre_ner_loss: 0.2258 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 80/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9942 - pre_ner_accuracy: 0.9947 - val_loss: 0.4942 - val_pre_intent_loss: 0.2685 - val_pre_ner_loss: 0.2257 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9680
# Epoch 81/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9947 - val_loss: 0.4942 - val_pre_intent_loss: 0.2681 - val_pre_ner_loss: 0.2261 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 82/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9947 - val_loss: 0.4949 - val_pre_intent_loss: 0.2691 - val_pre_ner_loss: 0.2258 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9680
# Epoch 83/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9947 - val_loss: 0.4943 - val_pre_intent_loss: 0.2680 - val_pre_ner_loss: 0.2263 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9680
# Epoch 84/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9947 - val_loss: 0.4952 - val_pre_intent_loss: 0.2694 - val_pre_ner_loss: 0.2258 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9680
# Epoch 85/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9948 - val_loss: 0.4930 - val_pre_intent_loss: 0.2673 - val_pre_ner_loss: 0.2257 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9680
# Epoch 86/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4941 - val_pre_intent_loss: 0.2686 - val_pre_ner_loss: 0.2255 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 87/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9948 - val_loss: 0.4914 - val_pre_intent_loss: 0.2662 - val_pre_ner_loss: 0.2252 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 88/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4935 - val_pre_intent_loss: 0.2682 - val_pre_ner_loss: 0.2253 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 89/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9948 - val_loss: 0.4911 - val_pre_intent_loss: 0.2656 - val_pre_ner_loss: 0.2255 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 90/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0126 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4936 - val_pre_intent_loss: 0.2682 - val_pre_ner_loss: 0.2254 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 91/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9948 - val_loss: 0.4921 - val_pre_intent_loss: 0.2660 - val_pre_ner_loss: 0.2261 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 92/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4939 - val_pre_intent_loss: 0.2682 - val_pre_ner_loss: 0.2257 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 93/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0056 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.4930 - val_pre_intent_loss: 0.2663 - val_pre_ner_loss: 0.2267 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 94/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0056 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4945 - val_pre_intent_loss: 0.2685 - val_pre_ner_loss: 0.2260 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 95/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0056 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.4936 - val_pre_intent_loss: 0.2666 - val_pre_ner_loss: 0.2270 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 96/500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0056 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4951 - val_pre_intent_loss: 0.2688 - val_pre_ner_loss: 0.2263 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 97/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0056 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.4942 - val_pre_intent_loss: 0.2669 - val_pre_ner_loss: 0.2274 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 98/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4957 - val_pre_intent_loss: 0.2691 - val_pre_ner_loss: 0.2266 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 99/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.4948 - val_pre_intent_loss: 0.2671 - val_pre_ner_loss: 0.2277 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 100/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4963 - val_pre_intent_loss: 0.2694 - val_pre_ner_loss: 0.2269 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 101/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.4952 - val_pre_intent_loss: 0.2673 - val_pre_ner_loss: 0.2279 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 102/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4968 - val_pre_intent_loss: 0.2697 - val_pre_ner_loss: 0.2271 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 103/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.4957 - val_pre_intent_loss: 0.2676 - val_pre_ner_loss: 0.2281 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 104/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4975 - val_pre_intent_loss: 0.2701 - val_pre_ner_loss: 0.2274 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 105/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0056 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.4962 - val_pre_intent_loss: 0.2679 - val_pre_ner_loss: 0.2283 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 106/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0057 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4981 - val_pre_intent_loss: 0.2705 - val_pre_ner_loss: 0.2276 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 107/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0125 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0056 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.4967 - val_pre_intent_loss: 0.2682 - val_pre_ner_loss: 0.2286 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 108/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0124 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0056 - pre_intent_accuracy: 0.9946 - pre_ner_accuracy: 0.9948 - val_loss: 0.4978 - val_pre_intent_loss: 0.2699 - val_pre_ner_loss: 0.2280 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 109/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0123 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0054 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9948 - val_loss: 0.4988 - val_pre_intent_loss: 0.2704 - val_pre_ner_loss: 0.2284 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 110/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0054 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9948 - val_loss: 0.4994 - val_pre_intent_loss: 0.2708 - val_pre_ner_loss: 0.2285 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 111/500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0054 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9948 - val_loss: 0.4998 - val_pre_intent_loss: 0.2711 - val_pre_ner_loss: 0.2287 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 112/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0054 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9948 - val_loss: 0.5002 - val_pre_intent_loss: 0.2714 - val_pre_ner_loss: 0.2287 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 113/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0054 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5005 - val_pre_intent_loss: 0.2717 - val_pre_ner_loss: 0.2288 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 114/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0054 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5008 - val_pre_intent_loss: 0.2720 - val_pre_ner_loss: 0.2288 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 115/500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0054 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5011 - val_pre_intent_loss: 0.2722 - val_pre_ner_loss: 0.2289 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 116/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0054 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5013 - val_pre_intent_loss: 0.2724 - val_pre_ner_loss: 0.2289 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 117/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0054 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5015 - val_pre_intent_loss: 0.2726 - val_pre_ner_loss: 0.2289 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 118/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5017 - val_pre_intent_loss: 0.2727 - val_pre_ner_loss: 0.2289 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 119/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5018 - val_pre_intent_loss: 0.2728 - val_pre_ner_loss: 0.2290 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 120/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5020 - val_pre_intent_loss: 0.2729 - val_pre_ner_loss: 0.2291 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 121/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5022 - val_pre_intent_loss: 0.2731 - val_pre_ner_loss: 0.2291 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 122/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5024 - val_pre_intent_loss: 0.2732 - val_pre_ner_loss: 0.2292 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 123/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5026 - val_pre_intent_loss: 0.2733 - val_pre_ner_loss: 0.2293 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 124/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5027 - val_pre_intent_loss: 0.2734 - val_pre_ner_loss: 0.2294 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 125/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5029 - val_pre_intent_loss: 0.2735 - val_pre_ner_loss: 0.2295 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 126/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5031 - val_pre_intent_loss: 0.2736 - val_pre_ner_loss: 0.2295 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 127/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5033 - val_pre_intent_loss: 0.2737 - val_pre_ner_loss: 0.2296 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 128/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5035 - val_pre_intent_loss: 0.2738 - val_pre_ner_loss: 0.2297 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 129/500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5037 - val_pre_intent_loss: 0.2739 - val_pre_ner_loss: 0.2298 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 130/500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5039 - val_pre_intent_loss: 0.2740 - val_pre_ner_loss: 0.2299 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 131/500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5041 - val_pre_intent_loss: 0.2741 - val_pre_ner_loss: 0.2300 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 132/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5042 - val_pre_intent_loss: 0.2741 - val_pre_ner_loss: 0.2301 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 133/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0122 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5044 - val_pre_intent_loss: 0.2742 - val_pre_ner_loss: 0.2302 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 134/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0121 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5046 - val_pre_intent_loss: 0.2743 - val_pre_ner_loss: 0.2303 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 135/500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0121 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5048 - val_pre_intent_loss: 0.2744 - val_pre_ner_loss: 0.2304 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 136/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0121 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5049 - val_pre_intent_loss: 0.2745 - val_pre_ner_loss: 0.2304 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9685
# Epoch 137/500
# 35/35 [==============================] - 0s 11ms/step - loss: 0.0121 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5051 - val_pre_intent_loss: 0.2746 - val_pre_ner_loss: 0.2305 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 138/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0121 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5053 - val_pre_intent_loss: 0.2747 - val_pre_ner_loss: 0.2306 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 139/500
# 35/35 [==============================] - 0s 12ms/step - loss: 0.0121 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5055 - val_pre_intent_loss: 0.2748 - val_pre_ner_loss: 0.2307 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 140/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0121 - pre_intent_loss: 0.0069 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5056 - val_pre_intent_loss: 0.2749 - val_pre_ner_loss: 0.2308 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 141/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0121 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5058 - val_pre_intent_loss: 0.2749 - val_pre_ner_loss: 0.2309 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 142/500
# 35/35 [==============================] - 0s 10ms/step - loss: 0.0121 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5060 - val_pre_intent_loss: 0.2750 - val_pre_ner_loss: 0.2310 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 143/500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0121 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5060 - val_pre_intent_loss: 0.2750 - val_pre_ner_loss: 0.2310 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 144/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0121 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5064 - val_pre_intent_loss: 0.2753 - val_pre_ner_loss: 0.2311 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 145/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0121 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5061 - val_pre_intent_loss: 0.2750 - val_pre_ner_loss: 0.2311 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# Epoch 146/500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0121 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0053 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9949 - val_loss: 0.5070 - val_pre_intent_loss: 0.2757 - val_pre_ner_loss: 0.2313 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9682
# ...
# Epoch 453/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9953 - val_loss: 0.5411 - val_pre_intent_loss: 0.2963 - val_pre_ner_loss: 0.2448 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 454/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9953 - val_loss: 0.5411 - val_pre_intent_loss: 0.2963 - val_pre_ner_loss: 0.2448 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 455/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9953 - val_loss: 0.5412 - val_pre_intent_loss: 0.2963 - val_pre_ner_loss: 0.2448 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 456/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9953 - val_loss: 0.5412 - val_pre_intent_loss: 0.2963 - val_pre_ner_loss: 0.2449 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 457/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9953 - val_loss: 0.5412 - val_pre_intent_loss: 0.2964 - val_pre_ner_loss: 0.2449 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 458/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5413 - val_pre_intent_loss: 0.2964 - val_pre_ner_loss: 0.2449 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 459/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5413 - val_pre_intent_loss: 0.2964 - val_pre_ner_loss: 0.2449 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 460/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5413 - val_pre_intent_loss: 0.2964 - val_pre_ner_loss: 0.2449 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 461/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5413 - val_pre_intent_loss: 0.2964 - val_pre_ner_loss: 0.2449 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 462/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5413 - val_pre_intent_loss: 0.2964 - val_pre_ner_loss: 0.2449 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 463/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5414 - val_pre_intent_loss: 0.2964 - val_pre_ner_loss: 0.2449 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 464/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5414 - val_pre_intent_loss: 0.2965 - val_pre_ner_loss: 0.2449 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 465/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5414 - val_pre_intent_loss: 0.2965 - val_pre_ner_loss: 0.2449 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 466/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5414 - val_pre_intent_loss: 0.2965 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 467/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5414 - val_pre_intent_loss: 0.2965 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 468/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5415 - val_pre_intent_loss: 0.2965 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 469/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5415 - val_pre_intent_loss: 0.2965 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 470/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5415 - val_pre_intent_loss: 0.2965 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 471/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5415 - val_pre_intent_loss: 0.2965 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 472/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5415 - val_pre_intent_loss: 0.2965 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 473/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5416 - val_pre_intent_loss: 0.2966 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 474/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5416 - val_pre_intent_loss: 0.2966 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 475/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5416 - val_pre_intent_loss: 0.2966 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 476/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5416 - val_pre_intent_loss: 0.2966 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 477/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5416 - val_pre_intent_loss: 0.2966 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 478/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5417 - val_pre_intent_loss: 0.2966 - val_pre_ner_loss: 0.2450 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 479/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5417 - val_pre_intent_loss: 0.2966 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 480/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5417 - val_pre_intent_loss: 0.2966 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 481/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5417 - val_pre_intent_loss: 0.2967 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 482/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5417 - val_pre_intent_loss: 0.2967 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 483/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5418 - val_pre_intent_loss: 0.2967 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 484/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5418 - val_pre_intent_loss: 0.2967 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 485/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5418 - val_pre_intent_loss: 0.2967 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 486/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5418 - val_pre_intent_loss: 0.2967 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 487/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5418 - val_pre_intent_loss: 0.2967 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 488/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5419 - val_pre_intent_loss: 0.2967 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 489/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5419 - val_pre_intent_loss: 0.2967 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 490/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5419 - val_pre_intent_loss: 0.2968 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 491/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5419 - val_pre_intent_loss: 0.2968 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 492/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5419 - val_pre_intent_loss: 0.2968 - val_pre_ner_loss: 0.2451 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 493/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5419 - val_pre_intent_loss: 0.2968 - val_pre_ner_loss: 0.2452 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 494/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5420 - val_pre_intent_loss: 0.2968 - val_pre_ner_loss: 0.2452 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 495/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5420 - val_pre_intent_loss: 0.2968 - val_pre_ner_loss: 0.2452 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 496/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5420 - val_pre_intent_loss: 0.2968 - val_pre_ner_loss: 0.2452 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 497/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5420 - val_pre_intent_loss: 0.2968 - val_pre_ner_loss: 0.2452 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 498/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5420 - val_pre_intent_loss: 0.2968 - val_pre_ner_loss: 0.2452 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 499/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5421 - val_pre_intent_loss: 0.2969 - val_pre_ner_loss: 0.2452 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
# Epoch 500/500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0116 - pre_intent_loss: 0.0068 - pre_ner_loss: 0.0048 - pre_intent_accuracy: 0.9951 - pre_ner_accuracy: 0.9954 - val_loss: 0.5421 - val_pre_intent_loss: 0.2969 - val_pre_ner_loss: 0.2452 - val_pre_intent_accuracy: 0.9583 - val_pre_ner_accuracy: 0.9672
